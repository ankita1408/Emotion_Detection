# %% [markdown]
# ## Emotion Detection

# %% [markdown]
# **import libraries**

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("tensorflow version:",tf.__version__)
# Out:
# WARNING:tensorflow:From C:\Users\ankit\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# tensorflow version: 2.15.0

# %% [markdown]
# **exploring Dataset**

# %%
images=glob("train//**/**")
for i in range(9):
    image=random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# **preparing data training**

# %%
img_size=48
batch_size =64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",target_size=(img_size,img_size),color_mode="grayscale",batch_size=batch_size,class_mode="categorical",shuffle=True)
datagen_validation = ImageDataGenerator()
validation_generator= datagen_train.flow_from_directory("test/",target_size=(img_size,img_size),color_mode="grayscale",batch_size=batch_size,class_mode="categorical",shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7169 images belonging to 7 classes.

# %% [markdown]
# **defining Model**

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters=filters, kernel_size=kernel_size, padding="same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.25)(x)
    return x

# %%
def Dens_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Dropout(0.25)(x)
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32, (3, 3))
    conv_2 = Convolution(inputs,64, (5, 5))
    conv_3 = Convolution(inputs,128, (3, 3))
    
    flatten = Flatten()(conv_3)
    
    dense_1 = Dens_f(flatten,256)  # Corrected function name here
    
    output = Dense(7, activation="softmax")(dense_1)
    model = Model(inputs=[inputs], outputs=[output])
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
model=model_fer((48,48,1))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\ankit\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\ankit\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\ankit\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18879239 (72.02 MB)
# Trainable params: 18878471 (72.02 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %% [markdown]
# **initializing the Model**

# %%
epochs = 15
steps_per_epoch = train_generator.n // train_generator.batch_size
validation_steps = validation_generator.n // validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weight.h5", monitor='val_accuracy', save_weights_only=True, mode='max', verbose=1)
callbacks = [checkpoint]

# %% [markdown]
# # traing the model

# %% [markdown]
# **the next cell takes time to compile**

# %%
history = model.fit(
    x=train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\ankit\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\ankit\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 448/448 [==============================] - ETA: 0s - loss: 1.6362 - accuracy: 0.3805
# Epoch 1: saving model to model_weight.h5
# 448/448 [==============================] - 1085s 2s/step - loss: 1.6362 - accuracy: 0.3805 - val_loss: 1.5530 - val_accuracy: 0.4067
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3497 - accuracy: 0.4894
# Epoch 2: saving model to model_weight.h5
# 448/448 [==============================] - 295s 657ms/step - loss: 1.3497 - accuracy: 0.4894 - val_loss: 1.5160 - val_accuracy: 0.4163
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1879 - accuracy: 0.5574
# Epoch 3: saving model to model_weight.h5
# 448/448 [==============================] - 299s 666ms/step - loss: 1.1879 - accuracy: 0.5574 - val_loss: 1.4514 - val_accuracy: 0.4443
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0564 - accuracy: 0.6140
# Epoch 4: saving model to model_weight.h5
# 448/448 [==============================] - 298s 664ms/step - loss: 1.0564 - accuracy: 0.6140 - val_loss: 1.7987 - val_accuracy: 0.3497
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9277 - accuracy: 0.6609
# Epoch 5: saving model to model_weight.h5
# 448/448 [==============================] - 297s 663ms/step - loss: 0.9277 - accuracy: 0.6609 - val_loss: 1.5916 - val_accuracy: 0.4333
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8116 - accuracy: 0.7075
# Epoch 6: saving model to model_weight.h5
# 448/448 [==============================] - 272s 606ms/step - loss: 0.8116 - accuracy: 0.7075 - val_loss: 1.5535 - val_accuracy: 0.4573
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6988 - accuracy: 0.7486
# Epoch 7: saving model to model_weight.h5
# 448/448 [==============================] - 196s 438ms/step - loss: 0.6988 - accuracy: 0.7486 - val_loss: 1.6342 - val_accuracy: 0.4318
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5943 - accuracy: 0.7925
# Epoch 8: saving model to model_weight.h5
# 448/448 [==============================] - 194s 433ms/step - loss: 0.5943 - accuracy: 0.7925 - val_loss: 1.6538 - val_accuracy: 0.4498
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5072 - accuracy: 0.8244
# Epoch 9: saving model to model_weight.h5
# 448/448 [==============================] - 193s 431ms/step - loss: 0.5072 - accuracy: 0.8244 - val_loss: 1.9644 - val_accuracy: 0.4069
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4374 - accuracy: 0.8486
# Epoch 10: saving model to model_weight.h5
# 448/448 [==============================] - 196s 437ms/step - loss: 0.4374 - accuracy: 0.8486 - val_loss: 1.7655 - val_accuracy: 0.4646
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3799 - accuracy: 0.8731
# Epoch 11: saving model to model_weight.h5
# 448/448 [==============================] - 193s 432ms/step - loss: 0.3799 - accuracy: 0.8731 - val_loss: 1.8295 - val_accuracy: 0.4828
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3400 - accuracy: 0.8852
# Epoch 12: saving model to model_weight.h5
# 448/448 [==============================] - 193s 431ms/step - loss: 0.3400 - accuracy: 0.8852 - val_loss: 1.8727 - val_accuracy: 0.5014
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3113 - accuracy: 0.8947
# Epoch 13: saving model to model_weight.h5
# 448/448 [==============================] - 194s 432ms/step - loss: 0.3113 - accuracy: 0.8947 - val_loss: 1.8908 - val_accuracy: 0.4788
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2740 - accuracy: 0.9098
# Epoch 14: saving model to model_weight.h5
# 448/448 [==============================] - 193s 431ms/step - loss: 0.2740 - accuracy: 0.9098 - val_loss: 1.8706 - val_accuracy: 0.4969
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.9184
# Epoch 15: saving model to model_weight.h5
# 448/448 [==============================] - 201s 448ms/step - loss: 0.2482 - accuracy: 0.9184 - val_loss: 1.9686 - val_accuracy: 0.4879

# %% [markdown]
# **Model Evalution**

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 10s 86ms/step - loss: 1.9683 - accuracy: 0.4879
# [1.9682917594909668, 0.4879341721534729]

# %% [markdown]
# **plotting loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **model Acurracy**

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Loss')
plt.legend(['train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **saving model**

# %%
model_json=model.to_json()
with open("model_a.json","w")as json_file:
    json_file.write(model_json)
